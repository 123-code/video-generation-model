# %%
# !git clone https://github.com/123-code/video-generation-model.git
# Out:
# fatal: destination path 'video-generation-model' already exists and is not an empty directory.

# %%
# !ls
# Out:
# video-generation-model

# %%
# !cd video-generation-model/

# %%
# !ls
# Out:
# video-generation-model

# %%
# !python video-generation-model/generate_latents.py
# Out:
# Using device: cuda
# Traceback (most recent call last):
#   File "/kaggle/working/video-generation-model/generate_latents.py", line 132, in <module>
#     generate_latents(args.data_dir, args.output_dir, args.batch_size, args.max_videos)
#   File "/kaggle/working/video-generation-model/generate_latents.py", line 84, in generate_latents
#     vae.load_state_dict(torch.load('vae_checkpoint_epoch_24.pth', map_location=device))
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 1425, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 751, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/serialization.py", line 732, in __init__
# ...
